# %% [markdown]
# # Drone validation
# In this notebook we will visualize one of the actual Hardware test runs. We picked test-run-6 as the best run to visualize because it was short and made use of all axes.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# test-run-6 data was exportet and inserted beneath.

# %%
testRun = [{
	"x": -0.02,
	"y": 0,
	"z": -10.45
}, {
	"x": -0.04,
	"y": -0.03,
	"z": -10.35
}, {
	"x": -0.11,
	"y": -0.03,
	"z": -10.35
}, {
	"x": -0.05,
	"y": 0.04,
	"z": -10.36
}, {
	"x": -0.56,
	"y": 0.21,
	"z": -10.21
}, {
	"x": -0.68,
	"y": 0.22,
	"z": -10.37
}, {
	"x": -1.47,
	"y": 0.13,
	"z": -10.14
}, {
	"x": -2.18,
	"y": 0.17,
	"z": -10.31
}, {
	"x": -3.34,
	"y": 0.09,
	"z": -9.36
}, {
	"x": -3.94,
	"y": 0.06,
	"z": -9.52
}, {
	"x": -4.87,
	"y": 0.17,
	"z": -8.46
}, {
	"x": -5.68,
	"y": 0,
	"z": -8.55
}, {
	"x": -5.99,
	"y": 0.01,
	"z": -8.09
}, {
	"x": -5.77,
	"y": 0.04,
	"z": -8.25
}, {
	"x": -3.79,
	"y": -0.06,
	"z": -9.51
}, {
	"x": -1.44,
	"y": 0.23,
	"z": -10.38
}, {
	"x": -0.07,
	"y": 0.45,
	"z": -11.1
}, {
	"x": -0.02,
	"y": 0.22,
	"z": -10.25
}, {
	"x": 0.5,
	"y": 0.07,
	"z": -10.36
}, {
	"x": 1.14,
	"y": 0.03,
	"z": -10.33
}, {
	"x": 2.22,
	"y": 0,
	"z": -10.13
}, {
	"x": 3.62,
	"y": -0.03,
	"z": -9.74
}, {
	"x": 5.13,
	"y": -0.17,
	"z": -9.02
}, {
	"x": 6.32,
	"y": -0.12,
	"z": -8.2
}, {
	"x": 6.88,
	"y": -0.13,
	"z": -7.74
}]

# %% [markdown]
# First we visualize each of the axes individually.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, figsize=(15, 10))
fig.suptitle('Acceleration plots for x, y, z-axis')
ax1.plot(xs)
ax1.set_ylabel('X accel')
ax1.set_xlabel('Time')

ax2.plot(ys)
ax2.set_ylabel('Y accel')
ax2.set_xlabel('Time')

ax3.plot(zs)
ax3.set_ylabel('Z accel')
ax3.set_xlabel('Time')

plt.show()

# %% [markdown]
# Next we can visualize them together in one 3D graph.

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(xs, ys, zs, 'gray')
